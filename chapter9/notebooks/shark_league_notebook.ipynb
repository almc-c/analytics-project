# %% [markdown]
# # Shark League Score
# ## Import Python Libraries

# %%
import pandas as pd

# we want to enable logging when working with the apis, but ignore them in the repo via the .gitignore file
import logging

# this will reference your swc_simple_client.py file as an alias
import swc_simple_client as swc

# %% [markdown]
# ## Configure Logging

# %%
# removes any existing logging handlers in the Codespace
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

# establish the new logger
logging.basicConfig(
    filename='shark_notebook.log',
    level=logging.INFO,
)

# %% [markdown]
# ## Setup notebook variables

# %%
# give the url in the browser of this Codespace without the trailing backslash which will be provided by the routes
# reminder, start the webserver in another terminal.. fastapi run ./app/main.py
# IMPORTANT: make it public, else you will hit 302 errors!  As needed, go to Ports and right click to confirm port visibility is set to Public
 
#base_url = "https://humble-halibut-557qvjxw5xgc7gvg.github.dev"
base_url = "https://humble-halibut-557qvjxw5xgc7gvg-8000.app.github.dev"

# then check your healthcheck endpoint and the weeks route: https://humble-halibut-557qvjxw5xgc7gvg-8000.app.github.dev/v0/weeks/ to verify its running

# %% [markdown]
# ## Get Max Scores
# ### Use endpoint: LIST_WEEKS_ENDPOINT

# %%
week_api_response = swc.call_api_endpoint(base_url,swc.LIST_WEEKS_ENDPOINT)
# Debug: Check the response
print(f"Status Code: {week_api_response.status_code}")
print(f"Response Content: {week_api_response.text}")
weeks_df = pd.DataFrame(week_api_response.json())
weeks_df['year'] = weeks_df['week_number'].str.slice(0,4).astype(int)

max_totals_grouped_df = weeks_df.groupby('year').agg(
    ppr_12_max_points=('ppr_12_max_points', 'sum'), 
    half_ppr_8_max_points=('half_ppr_8_max_points', 'sum')
)

display(max_totals_grouped_df)
# Out:
# Status Code: 200
# Response Content: [{"week_number":"202301","ppr_8_max_points":864.0,"ppr_10_max_points":1040.0,"ppr_12_max_points":1392.0,"ppr_14_max_points":1358.0,"half_ppr_8_max_points":888.0,"half_ppr_10_max_points":860.0,"half_ppr_12_max_points":1332.0,"half_ppr_14_max_points":1162.0,"std_8_max_points":848.0,"std_10_max_points":970.0,"std_12_max_points":1260.0,"std_14_max_points":1428.0,"last_changed_date":"2024-09-03"},{"week_number":"202302","ppr_8_max_points":680.0,"ppr_10_max_points":1220.0,"ppr_12_max_points":1224.0,"ppr_14_max_points":1204.0,"half_ppr_8_max_points":744.0,"half_ppr_10_max_points":1030.0,"half_ppr_12_max_points":1416.0,"half_ppr_14_max_points":1792.0,"std_8_max_points":832.0,"std_10_max_points":970.0,"std_12_max_points":1260.0,"std_14_max_points":1680.0,"last_changed_date":"2024-09-03"},{"week_number":"202303","ppr_8_max_points":640.0,"ppr_10_max_points":960.0,"ppr_12_max_points":1368.0,"ppr_14_max_points":1540.0,"half_ppr_8_max_points":1008.0,"half_ppr_10_max_points":890.0,"half_ppr_12_max_points":1464.0,"half_ppr_14_max_points":1064.0,"std_8_max_points":632.0,"std_10_max_points":730.0,"std_12_max_points":936.0,"std_14_max_points":1092.0,"last_changed_date":"2024-09-03"},{"week_number":"202304","ppr_8_max_points":1048.0,"ppr_10_max_points":1270.0,"ppr_12_max_points":1092.0,"ppr_14_max_points":1932.0,"half_ppr_8_max_points":984.0,"half_ppr_10_max_points":960.0,"half_ppr_12_max_points":912.0,"half_ppr_14_max_points":1204.0,"std_8_max_points":960.0,"std_10_max_points":1240.0,"std_12_max_points":1452.0,"std_14_max_points":1708.0,"last_changed_date":"2024-09-03"},{"week_number":"202305","ppr_8_max_points":1024.0,"ppr_10_max_points":800.0,"ppr_12_max_points":1392.0,"ppr_14_max_points":1344.0,"half_ppr_8_max_points":896.0,"half_ppr_10_max_points":860.0,"half_ppr_12_max_points":1008.0,"half_ppr_14_max_points":1190.0,"std_8_max_points":912.0,"std_10_max_points":1260.0,"std_12_max_points":924.0,"std_14_max_points":1806.0,"last_changed_date":"2024-09-03"},{"week_number":"202306","ppr_8_max_points":912.0,"ppr_10_max_points":910.0,"ppr_12_max_points":960.0,"ppr_14_max_points":1680.0,"half_ppr_8_max_points":1000.0,"half_ppr_10_max_points":960.0,"half_ppr_12_max_points":1080.0,"half_ppr_14_max_points":1204.0,"std_8_max_points":952.0,"std_10_max_points":1000.0,"std_12_max_points":1140.0,"std_14_max_points":1638.0,"last_changed_date":"2024-09-03"},{"week_number":"202307","ppr_8_max_points":768.0,"ppr_10_max_points":1340.0,"ppr_12_max_points":1368.0,"ppr_14_max_points":1820.0,"half_ppr_8_max_points":992.0,"half_ppr_10_max_points":1120.0,"half_ppr_12_max_points":1260.0,"half_ppr_14_max_points":1876.0,"std_8_max_points":832.0,"std_10_max_points":1160.0,"std_12_max_points":840.0,"std_14_max_points":1582.0,"last_changed_date":"2024-09-03"},{"week_number":"202308","ppr_8_max_points":720.0,"ppr_10_max_points":1160.0,"ppr_12_max_points":1212.0,"ppr_14_max_points":1554.0,"half_ppr_8_max_points":904.0,"half_ppr_10_max_points":760.0,"half_ppr_12_max_points":924.0,"half_ppr_14_max_points":1218.0,"std_8_max_points":672.0,"std_10_max_points":720.0,"std_12_max_points":1380.0,"std_14_max_points":994.0,"last_changed_date":"2024-09-03"},{"week_number":"202309","ppr_8_max_points":864.0,"ppr_10_max_points":940.0,"ppr_12_max_points":1164.0,"ppr_14_max_points":1932.0,"half_ppr_8_max_points":632.0,"half_ppr_10_max_points":1270.0,"half_ppr_12_max_points":1116.0,"half_ppr_14_max_points":1680.0,"std_8_max_points":592.0,"std_10_max_points":780.0,"std_12_max_points":1500.0,"std_14_max_points":1008.0,"last_changed_date":"2024-09-03"},{"week_number":"202310","ppr_8_max_points":1048.0,"ppr_10_max_points":1140.0,"ppr_12_max_points":1260.0,"ppr_14_max_points":1246.0,"half_ppr_8_max_points":616.0,"half_ppr_10_max_points":1080.0,"half_ppr_12_max_points":1452.0,"half_ppr_14_max_points":1876.0,"std_8_max_points":848.0,"std_10_max_points":850.0,"std_12_max_points":1200.0,"std_14_max_points":1358.0,"last_changed_date":"2024-09-03"},{"week_number":"202311","ppr_8_max_poin ...
#       ppr_12_max_points  half_ppr_8_max_points
# year
# 2023            22570.0                15401.0
